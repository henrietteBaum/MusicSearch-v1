# %% [markdown]
# # Python Music-Seach App Dokumentation

# %% [markdown]
# Music-Search ist ein Lernprojekt, das erklärt, wie man in einem Python Skript ein Modul verwendet, Benutzereingaben abfragt und eine API-Abfrage integriert.
#
# Wir verwenden das Modul „requests” und die iTunes-API. Der Benutzer wird aufgefordert, einen Suchbegriff einzugeben, der dann in der iTunes-Datenbank gesucht wird. Künstler und Alben, die dem Suchbegriff entsprechen, werden als Ausgabe im Terminal zurückgegeben.
#
# Voraussetzungen:
#
# - Eine aktuelle Python-Installation auf Ihrem Computer,
# - der Paketmanager pip,
# - ein Editor oder vorzugsweise eine IDE.
#
# Erstellen Sie eine virtuelle Umgebung für das Projekt.

# %% [markdown]
# ## Das vollständige Python-Skript:

# %%
import requests

BASE_URL = "https://itunes.apple.com/search"

search_term = input("Enter a search term: ")

payloyd = {
    "term": search_term,
    "entity": "album",
    "limit": 5
}

response = requests.get(BASE_URL, params=payloyd)
response_dict =response.json()

result_count = response_dict["resultCount"]
print("The search returned ", result_count, "results.")

for result in response_dict["results"]:
    artist = result["artistName"]
    album = result["collectionName"]
    tracks = result["trackCount"]
    print("Artist:", artist)
    print("Album:", album)
    print("Track Count:", tracks)
    
#print(f"completed url: ", {response.url})
#print(response_json)

# %% [markdown]
# ___

# %%
## Erläutrungen::

# %%
import requests

# %% [markdown]
# The import keyword makes code in one module available in another, eg. in your script.
# ` requests` is a library for sending HTTP requests and processing the responses received.

# %%
BASE_URL = "https://itunes.apple.com/search"

# %% [markdown]
# `BASE_URL` is a static variable, which we will use to store the URL to the Apple iTunes database.

# %%
search_term = input("Enter a search term: ")

# %% [markdown]
# Die Python-Funktion  `input()` ermöglicht es dem Benutzer, etwas einzugeben, das in der Variablen `search_term` gespeichert wird. Der Parameter für input() ist eine Eingabeaufforderung, die angezeigt wird und den Benutzer auffordert, einen Suchbegriff einzugeben.

# %%
payloyd = {
    "term": search_term,
    "entity": "album",
    "limit": 5
}

# %% [markdown]
# Andere entity types:
# - musicArtist,
# - musicTrack,
# - song
#
# Ein Dictionary mit den für die Suchanfrage erforderlichen Parametern wird in der Variablen ` payload` gespeichert. Der vom Benutzer eingegebene Suchbegriff wird in ` search_term` gespeichert. Ansonsten finden Sie die möglichen Bezeichnungen – wie Entität und Begriff – in der API-Dokumentation.
#
# „limit” ist ein Wert, den wir nur für die ersten Tests festlegen. Später können Sie ein weiteres Eingabefeld erstellen, in dem der Benutzer die Anzahl der anzuzeigenden Ergebnisse festlegen kann.
#
# https://developer.apple.com/library/archive/documentation/AudioVideo/Conceptual/iTuneSearchAPI/Searching.html#//apple_ref/doc/uid/TP40017632-CH5-SW2

# %%
response = requests.get(BASE_URL, params=payloyd)

# %% [markdown]
# Die Variable `response` das response-Objekt, das vom iTunes-Server zurückgegeben wird.
#
# Die Funktion get() aus der Bibliothek ` requests` sendet eine GET-Anfrage an eine Webadresse um hier Daten ITunes-API abzurufen. Sie gibt ein Response-Objekt zurück, das den Server-Status, den Inhalt (Text, JSON), Header und mehr enthält, um die abgerufene Ressource einfach weiterzuverarbeiten

# %%
response_dict = response.json()

# %% [markdown]
# Die ` response.json()` Methode wird verwendet, um den JSON-formatierten Inhalt einer HTTP-Antwort in ein natives Python-Objekt (typischerweise ein Dictionary oder eine Liste) zu deserialisieren (umzuwandeln). Hier speichern wir das Dictionary in der Variablen response_dict.

# %% [markdown]
# Lässt man sich das Dictionary mit einem print-Befehl ausgeben, erhält man Folgendes:
# ```bash
# response_dict:  {'resultCount': 2, 'results': [{'wrapperType': 'collection', 'collectionType': 'Album', 'artistId': 454295032, 'collectionId': 1533983552, 'amgArtistId': 140996, 'artistName': 'Hans Zimmer', 'collectionName': 'Interstellar (Original Motion Picture Soundtrack) [Expanded Edition]', 'collectionCensoredName': 'Interstellar (Original Motion Picture Soundtrack) [Expanded Edition]', 'artistViewUrl': 'https://music.apple.com/us/artist/hans-zimmer/454295032?uo=4', 'collectionViewUrl': 'https://music.apple.com/us/album/interstellar-original-motion-picture-soundtrack-expanded/1533983552?uo=4', 'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music125/v4/f4/5b/73/f45b735a-8d7a-9713-b217-0f8e1593c28b/794043201943.jpg/60x60bb.jpg', 'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music125/v4/f4/5b/73/f45b735a-8d7a-9713-b217-0f8e1593c28b/794043201943.jpg/100x100bb.jpg', 'collectionPrice': 14.99, 'collectionExplicitness': 'notExplicit', 'trackCount': 30, 'copyright': '℗ 2014 This compilation WaterTower Music as licensee for Warner Bros. Entertainment Inc.', 'country': 'USA', 'currency': 'USD', 'releaseDate': '2014-11-18T08:00:00Z', 'primaryGenreName': 'Soundtrack'}, {'wrapperType': 'collection', 'collectionType': 'Album', 'artistId': 36270, 'collectionId': 1476064528, 'artistName': 'Various Artists', 'collectionName': 'Happy Classical Music', 'collectionCensoredName': 'Happy Classical Music', 'collectionViewUrl': 'https://music.apple.com/us/album/happy-classical-music/1476064528?uo=4', 'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/62/ee/a2/62eea269-a73f-ef5e-2d1d-4eabd704a4a2/cover.jpg/60x60bb.jpg', 'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/62/ee/a2/62eea269-a73f-ef5e-2d1d-4eabd704a4a2/cover.jpg/100x100bb.jpg', 'collectionPrice': 7.99, 'collectionExplicitness': 'notExplicit', 'trackCount': 22, 'copyright': '℗ 2019 Klassic ALL', 'country': 'USA', 'currency': 'USD', 'releaseDate': '2019-07-25T07:00:00Z', 'primaryGenreName': 'Classical'}]}
# ```
# Wir haben das Ausgabe-Limit hier auf 2 gestzt. Das Dictionary enthält zwei keys:
# - **resultCount** mit dem Wert 2
# - **results** hat als Wert eine Liste [], die selbst wieder zwei Dictionaries {} enthält.
#
# Sie können daran erkenne, welche Schlüssel zur Verfügung stehen, um Werte abzufragen.
# Das tun wir dann auch in der nächsten Zeile:

# %%
result_count = response_dict["resultCount"]

# %% [markdown]
# Wir rufen aus dem Dictionary den Wert zum Schlüssel ` resultCount` ab und speichern ihn in der Variablen ` result_count`.

# %%
print("The search returned ", result_count, "results.")

# %% [markdown]
# Mit dem print-Befehl wird der Inhalt der Variabeln `result_count` ausgegeben.

# %%
for result in response_dict["results"]:
    artist = result["artistName"]
    album = result["collectionName"]
    tracks = result["trackCount"]
    print("Artist:", artist)
    print("Album:", album)
    print("Track Count:", tracks)

# %% [markdown]
# Schließlich iterieren wir mit einem for-loop über die Liste, die dem key `results` zugeordnet ist und speichern die Werte der einzelnen keys, die wir anzeigen möchten, jeweils in einer Variablen. Der Inhalt dieser Variablen wird in jedem Schleifendurchgang mit `print` ausgegeben.

# %% [markdown]
# ## Die Ausgabe des Programms im Terminal
# (auf 2 Ergebnisse begrenzt)

# %%
Enter a search term: Forelle
The search returned  2 results.
Artist: Hans Zimmer
Album: Interstellar (Original Motion Picture Soundtrack) [Expanded Edition]
Track Count: 30
Artist: Various Artists
Album: Happy Classical Music
Track Count: 22
